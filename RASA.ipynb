# %%
nlu_md = """

## intent:upload_data
- upload data
- upload data set
- can you upload the data
- load the data

## intent:describe_data
- describe the data
- describe the dataset
- describe data

## intent: clean_data
- clean the data
- clean the dataset
- remove nan values from the data
- remove nan values
- remove null values
- drop nan values
- drop null values
- remove nan values from all rows

## intent: features
- what are your features
- tell me what you can do
- what can you do
- what all functions can you perform

##intent: visualize
- visualize the data
- generate plots
- create plots
- Generate [distribution plot](plot_type)
- can you create [distribution plot](plot_type)
- create [distribution graph](plot_type)
- Generate [pair plot](plot_type)
- can you create [pair plot](plot_type)
- create [pair plot](plot_type)
- Generate [scatter plot](plot_type)
- can you create [scatter plot](plot_type)
- create [scatter plot](plot_type)
- Generate [line plot](plot_type)
- can you create [line plot](plot_type)
- create [line graph](plot_type)
- Generate [histogram](plot_type)
- can you create [histogram](plot_type)
- create [histogram](plot_type)
- Generate [overlaid histogram](plot_type)
- can you create [overlaid histogram](plot_type)
- create [overlaid histogram](plot_type)
- Generate [bar plot](plot_type)
- can you create [bar plot](plot_type)
- create [bar graph](plot_type)
- Generate [stacked bar plot](plot_type)
- can you create [stacked bar plot](plot_type)
- create [stacked bar graph](plot_type)

## synonym:distribution plot
- distribution graph
- distribution chart

## synonym:pair plot
- pair chart
- pair graph

## synonym:scatter plot
- scatter graph
- scatter chart

## synonym:line plot
- line graph
- line chart

## synonym:histogram
- histogram chart
- histogram graph

## synonym:overlaid historgram
- overlaid histogram chart
- overlaid histogram graph

## synonym:bar plot
- bar graph
- bar chart

## synonym:stacked bar plot
- stacked bar graph
- stacked bar chart

## lookup: plot_type
- distribution plot
- pair plot
- scatter plot
- line plot
- histogram
- overlaid historgram
- bar plot
- stacked bar plot

## intent: build_model
- Build model
- Build machine learning model
- Build a classifier
- Generate model
- Can you build a [k neighbors](model_name) classifier        
- Create [logistic regression](model_name) model
- build [gaussian nb](model_name) model
- build [support vector](model_name) model
- build [decision tree](model_name) model
- build [decision tree](model_name) classifier


## lookup: model_name
- logisitic regression
- k neighbors classifier
- decision tree classifier
- gaussian nb classifier
- support vector classifier

## synonym:kneighbors
- knn
- k nearest neighbours
- k nearest neighbors
- KNN
- K-NN
- k neighbors

## synonym:support vector
- svm
- svc
- support vector machines

## intent:data_exploration
- explore the data
- can you help me explore the dataset
- help me explore the data
- show me [top](head) [5](number) rows
- show me [first](head) [10](number) rows
- show me [bottom](tail) [3](number) rows
- show the [top](head) [three](number) rows
- show me [last](tail) [7](number) rows
- load the [first](head) [five](number) rows
- can you show me the [last](tail) [ten](number) rows
- Show the [data distribution](data_distribution)
- [Data distribution](data_distribution)
- can you show the [distribution](data_distribution) of the data
- Show the different [data types](data_type) in the dataset
- Show the [data types](data_type)
- [Data types](data_type)
- what are the different [types of data](data_type)
- Show me the [unique](unique) values in the dataset
- Show me the [unique values](unique)
- [Unique](unique) values
- what are the [unique rows](unique) in the data
- Show me columns with [missing](missing) values
- [Missing values](missing)
- Columns with [missing](missing) values
- show the columns with [missing](missing) values

## regex: number
- [0-9]+

"""
# %store nlu_md > nlu.md
# Out:
# Writing 'nlu_md' (str) to file 'nlu.md'.

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config
from rasa_nlu.evaluate import run_evaluation

# %%
import json
def intent_print(o):
    print(json.dumps(o, indent=2))

# %%
tensor_config = """
language: "en"

pipeline:
- name: "tokenizer_whitespace"
- name: "intent_entity_featurizer_regex"
- name: "ner_crf"
- name: "ner_synonyms"
- name: "intent_featurizer_count_vectors"
- name: "intent_classifier_tensorflow_embedding"
  intent_tokenization_flag: true
  intent_split_symbol: "+"
"""
# %store tensor_config > tensor_config.yml
# Out:
# Writing 'tensor_config' (str) to file 'tensor_config.yml'.

# %%
# loading the nlu training samples
training_data = load_data("nlu.md")

# trainer to educate our pipeline
trainer = Trainer(config.load("tensor_config.yml"))

# train the model!
interpreter = trainer.train(training_data)

# store it for future use
model_directory = trainer.persist("./models/nlu", fixed_model_name="tensor")
# Out:
# Epochs: 100%|█████████████████████████████████████████████████| 300/300 [00:05<00:00, 50.14it/s, loss=0.104, acc=1.000]

# %%
run_evaluation("nlu.md", model_directory)
# Out:
# WARNING:tensorflow:From C:\Users\Shoumik\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from C:\Users\Shoumik\Desktop\Jupyter\voice bot\Machine-learning-Voice-Assistant-master\Machine-learning-Voice-Assistant- v0.4\./models/nlu\default\tensor\intent_classifier_tensorflow_embedding.ckpt
# {'intent_evaluation': {'predictions': [{'text': 'upload data',
#     'intent': 'upload_data',
#     'predicted': 'upload_data',
#     'confidence': 0.9684752821922302},
#    {'text': 'upload data set',
#     'intent': 'upload_data',
#     'predicted': 'upload_data',
#     'confidence': 0.9669968485832214},
#    {'text': 'can you upload the data',
#     'intent': 'upload_data',
#     'predicted': 'upload_data',
#     'confidence': 0.9754041433334351},
#    {'text': 'load the data',
#     'intent': 'upload_data',
#     'predicted': 'upload_data',
#     'confidence': 0.9790684580802917},
#    {'text': 'describe the data',
#     'intent': 'describe_data',
#     'predicted': 'describe_data',
#     'confidence': 0.9703161716461182},
#    {'text': 'describe the dataset',
#     'intent': 'describe_data',
#     'predicted': 'describe_data',
#     'confidence': 0.9602063894271851},
#    {'text': 'describe data',
#     'intent': 'describe_data',
#     'predicted': 'describe_data',
#     'confidence': 0.9627252817153931},
#    {'text': 'clean the data',
#     'intent': 'clean_data',
#     'predicted': 'clean_data',
#     'confidence': 0.9584376811981201},
#    {'text': 'clean the dataset',
#     'intent': 'clean_data',
#     'predicted': 'clean_data',
#     'confidence': 0.9832906126976013},
#    {'text': 'remove nan values from the data',
#     'intent': 'clean_data',
#     'predicted': 'clean_data',
#     'confidence': 0.9511328935623169},
#    {'text': 'remove nan values',
#     'intent': 'clean_data',
#     'predicted': 'clean_data',
#     'confidence': 0.9720036387443542},
#    {'text': 'remove null values',
#     'intent': 'clean_data',
#     'predicted': 'clean_data',
#     'confidence': 0.9772151112556458},
#    {'text': 'drop nan values',
#     'intent': 'clean_data',
#     'predicted': 'clean_data',
#     'confidence': 0.9669041633605957},
#    {'text': 'drop null values',
#     'intent': 'clean_data',
#     'predicted': 'clean_data',
#     'confidence': 0.9714333415031433},
#    {'text': 'remove nan values from all rows',
#     'intent': 'clean_data',
#     'predicted': 'clean_data',
#     'confidence': 0.9666897058486938},
#    {'text': 'what are your features',
#     'intent': 'features',
#     'predicted': 'features',
#     'confidence': 0.9521621465682983},
#    {'text': 'tell me what you can do',
#     'intent': 'features',
#     'predicted': 'features',
#     'confidence': 0.9477826356887817},
#    {'text': 'what can you do',
#     'intent': 'features',
#     'predicted': 'features',
#     'confidence': 0.9585934281349182},
#    {'text': 'what all functions can you perform',
#     'intent': 'features',
#     'predicted': 'features',
#     'confidence': 0.9634042978286743},
#    {'text': 'visualize the data',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9484583735466003},
#    {'text': 'generate plots',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9579189419746399},
#    {'text': 'create plots',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9668611288070679},
#    {'text': 'Generate distribution plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9729181528091431},
#    {'text': 'can you create distribution plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9817625880241394},
#    {'text': 'create distribution graph',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9798887372016907},
#    {'text': 'Generate pair plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9765807390213013},
#    {'text': 'can you create pair plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9852989315986633},
#    {'text': 'create pair plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9840043783187866},
#    {'text': 'Generate scatter plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9659878611564636},
#    {'text': 'can you create scatter plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9764460921287537},
#    {'text': 'create scatter plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9744740128517151},
#    {'text': 'Generate line plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9601951241493225},
#    {'text': 'can you create line plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9791264533996582},
#    {'text': 'create line graph',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9697428345680237},
#    {'text': 'Generate histogram',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9591127038002014},
#    {'text': 'can you create histogram',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9731638431549072},
#    {'text': 'create histogram',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9716280698776245},
#    {'text': 'Generate overlaid histogram',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9655987620353699},
#    {'text': 'can you create overlaid histogram',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9816797375679016},
#    {'text': 'create overlaid histogram',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9760974645614624},
#    {'text': 'Generate bar plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9655473828315735},
#    {'text': 'can you create bar plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9801123738288879},
#    {'text': 'create bar graph',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9677102565765381},
#    {'text': 'Generate stacked bar plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.969558835029602},
#    {'text': 'can you create stacked bar plot',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9822826981544495},
#    {'text': 'create stacked bar graph',
#     'intent': 'visualize',
#     'predicted': 'visualize',
#     'confidence': 0.9743492603302002},
#    {'text': 'Build model',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9663428068161011},
#    {'text': 'Build machine learning model',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9723648428916931},
#    {'text': 'Build a classifier',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9569317102432251},
#    {'text': 'Generate model',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9752670526504517},
#    {'text': 'Can you build a k neighbors classifier',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9734331369400024},
#    {'text': 'Create logistic regression model',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9666266441345215},
#    {'text': 'build decision tree model',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9680560827255249},
#    {'text': 'build decision tree classifier',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9611067175865173},
#    {'text': 'build gaussian nb model',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.967564582824707},
#    {'text': 'build support vector model',
#     'intent': 'build_model',
#     'predicted': 'build_model',
#     'confidence': 0.9694879651069641},
#    {'text': 'explore the data',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9634378552436829},
#    {'text': 'can you help me explore the dataset',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9804903268814087},
#    {'text': 'help me explore the data',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9636766314506531},
#    {'text': 'show me top 5 rows',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9720320105552673},
#    {'text': 'show me first 10 rows',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9666686654090881},
#    {'text': 'show me bottom 3 rows',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9703996777534485},
#    {'text': 'show the top three rows',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9693056344985962},
#    {'text': 'show me last 7 rows',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9685843586921692},
#    {'text': 'load the first five rows',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9848335981369019},
#    {'text': 'can you show me the last ten rows',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.977121114730835},
#    {'text': 'Show the data distribution',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9744195938110352},
#    {'text': 'Data distribution',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9636532664299011},
#    {'text': 'can you show the distribution of the data',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9731132984161377},
#    {'text': 'Show the different data types in the dataset',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9598159193992615},
#    {'text': 'Show the data types',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9712377786636353},
#    {'text': 'Data types',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.956680953502655},
#    {'text': 'what are the different types of data',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9821949005126953},
#    {'text': 'Show me the unique values in the dataset',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9637462496757507},
#    {'text': 'Show me the unique values',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9652280807495117},
#    {'text': 'Unique values',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9643732905387878},
#    {'text': 'what are the unique rows in the data',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9875850081443787},
#    {'text': 'Show me columns with missing values',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9668545126914978},
#    {'text': 'Missing values',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9652891755104065},
#    {'text': 'Columns with missing values',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9734538793563843},
#    {'text': 'show the columns with missing values',
#     'intent': 'data_exploration',
#     'predicted': 'data_exploration',
#     'confidence': 0.9717164635658264}],
#   'report': '                  precision    recall  f1-score   support\n\n     build_model       1.00      1.00      1.00        10\n      clean_data       1.00      1.00      1.00         8\ndata_exploration       1.00      1.00      1.00        25\n   describe_data       1.00      1.00      1.00         3\n        features       1.00      1.00      1.00         4\n     upload_data       1.00      1.00      1.00         4\n       visualize       1.00      1.00      1.00        27\n\n       micro avg       1.00      1.00      1.00        81\n       macro avg       1.00      1.00      1.00        81\n    weighted avg       1.00      1.00      1.00        81\n',
#   'precision': 1.0,
#   'f1_score': 1.0,
#   'accuracy': 1.0},
#  'entity_evaluation': {'ner_crf': {'report': '                   precision    recall  f1-score   support\n\ndata_distribution       1.00      1.00      1.00         5\n        data_type       1.00      1.00      1.00         9\n             head       1.00      1.00      1.00         4\n          missing       1.00      1.00      1.00         5\n       model_name       1.00      1.00      1.00        12\n        no_entity       1.00      1.00      1.00       234\n           number       1.00      1.00      1.00         7\n        plot_type       1.00      1.00      1.00        48\n             tail       1.00      1.00      1.00         3\n           unique       1.00      0.83      0.91         6\n\n        micro avg       1.00      1.00      1.00       333\n        macro avg       1.00      0.98      0.99       333\n     weighted avg       1.00      1.00      1.00       333\n',
#    'precision': 0.99700977573318,
#    'f1_score': 0.9968636983562357,
#    'accuracy': 0.996996996996997}}}

# %%
intent_print(interpreter.parse("show me top 5 rows"))
# Out:
# {
#   "intent": {
#     "name": "data_exploration",
#     "confidence": 0.9543548226356506
#   },
#   "entities": [
#     {
#       "start": 8,
#       "end": 11,
#       "value": "top",
#       "entity": "head",
#       "confidence": 0.8077366429112551,
#       "extractor": "ner_crf"
#     },
#     {
#       "start": 12,
#       "end": 13,
#       "value": "5",
#       "entity": "number",
#       "confidence": 0.891429461728507,
#       "extractor": "ner_crf"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "data_exploration",
#       "confidence": 0.9543548226356506
#     },
#     {
#       "name": "build_model",
#       "confidence": 0.07595732808113098
#     },
#     {
#       "name": "upload_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "features",
#       "confidence": 0.0
#     },
#     {
#       "name": "describe_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "visualize",
#       "confidence": 0.0
#     },
#     {
#       "name": "clean_data",
#       "confidence": 0.0
#     }
#   ],
#   "text": "show me top 5 rows"
# }

# %%
intent_print(interpreter.parse('show me top 10 rows'))
# Out:
# {
#   "intent": {
#     "name": "data_exploration",
#     "confidence": 0.9543548226356506
#   },
#   "entities": [
#     {
#       "start": 8,
#       "end": 11,
#       "value": "top",
#       "entity": "head",
#       "confidence": 0.7051137089590973,
#       "extractor": "ner_crf"
#     },
#     {
#       "start": 12,
#       "end": 14,
#       "value": "10",
#       "entity": "number",
#       "confidence": 0.8268789205224722,
#       "extractor": "ner_crf"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "data_exploration",
#       "confidence": 0.9543548226356506
#     },
#     {
#       "name": "build_model",
#       "confidence": 0.07595732808113098
#     },
#     {
#       "name": "upload_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "features",
#       "confidence": 0.0
#     },
#     {
#       "name": "describe_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "visualize",
#       "confidence": 0.0
#     },
#     {
#       "name": "clean_data",
#       "confidence": 0.0
#     }
#   ],
#   "text": "show me top 10 rows"
# }

# %%
intent_print(interpreter.parse('load the first five rows'))
# Out:
# {
#   "intent": {
#     "name": "data_exploration",
#     "confidence": 0.9664868116378784
#   },
#   "entities": [
#     {
#       "start": 9,
#       "end": 14,
#       "value": "first",
#       "entity": "head",
#       "confidence": 0.850055607010122,
#       "extractor": "ner_crf"
#     },
#     {
#       "start": 15,
#       "end": 19,
#       "value": "five",
#       "entity": "number",
#       "confidence": 0.8714769569873854,
#       "extractor": "ner_crf"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "data_exploration",
#       "confidence": 0.9664868116378784
#     },
#     {
#       "name": "upload_data",
#       "confidence": 0.11891564726829529
#     },
#     {
#       "name": "build_model",
#       "confidence": 0.023528505116701126
#     },
#     {
#       "name": "describe_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "features",
#       "confidence": 0.0
#     },
#     {
#       "name": "visualize",
#       "confidence": 0.0
#     },
#     {
#       "name": "clean_data",
#       "confidence": 0.0
#     }
#   ],
#   "text": "load the first five rows"
# }

# %%
intent_print(interpreter.parse('can you show me the last ten rows'))
# Out:
# {
#   "intent": {
#     "name": "data_exploration",
#     "confidence": 0.9474862813949585
#   },
#   "entities": [
#     {
#       "start": 20,
#       "end": 24,
#       "value": "last",
#       "entity": "tail",
#       "confidence": 0.8506571323455502,
#       "extractor": "ner_crf"
#     },
#     {
#       "start": 25,
#       "end": 28,
#       "value": "ten",
#       "entity": "number",
#       "confidence": 0.873804690437395,
#       "extractor": "ner_crf"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "data_exploration",
#       "confidence": 0.9474862813949585
#     },
#     {
#       "name": "features",
#       "confidence": 0.07322325557470322
#     },
#     {
#       "name": "upload_data",
#       "confidence": 0.0665227398276329
#     },
#     {
#       "name": "visualize",
#       "confidence": 0.0
#     },
#     {
#       "name": "describe_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "build_model",
#       "confidence": 0.0
#     },
#     {
#       "name": "clean_data",
#       "confidence": 0.0
#     }
#   ],
#   "text": "can you show me the last ten rows"
# }

# %%
intent_print(interpreter.parse('show me the missing values in the dataset'))
# Out:
# {
#   "intent": {
#     "name": "data_exploration",
#     "confidence": 0.9485447406768799
#   },
#   "entities": [
#     {
#       "start": 12,
#       "end": 19,
#       "value": "missing",
#       "entity": "missing",
#       "confidence": 0.8155862649720363,
#       "extractor": "ner_crf"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "data_exploration",
#       "confidence": 0.9485447406768799
#     },
#     {
#       "name": "describe_data",
#       "confidence": 0.1367170214653015
#     },
#     {
#       "name": "upload_data",
#       "confidence": 0.011471053585410118
#     },
#     {
#       "name": "build_model",
#       "confidence": 0.0
#     },
#     {
#       "name": "visualize",
#       "confidence": 0.0
#     },
#     {
#       "name": "features",
#       "confidence": 0.0
#     },
#     {
#       "name": "clean_data",
#       "confidence": 0.0
#     }
#   ],
#   "text": "show me the missing values in the dataset"
# }

# %%
intent_print(interpreter.parse('can you build a logistic regression model'))
# Out:
# {
#   "intent": {
#     "name": "build_model",
#     "confidence": 0.9256531000137329
#   },
#   "entities": [
#     {
#       "start": 16,
#       "end": 35,
#       "value": "logistic regression",
#       "entity": "model_name",
#       "confidence": 0.8648730367752118,
#       "extractor": "ner_crf"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "build_model",
#       "confidence": 0.9256531000137329
#     },
#     {
#       "name": "features",
#       "confidence": 0.26887407898902893
#     },
#     {
#       "name": "upload_data",
#       "confidence": 0.11083553731441498
#     },
#     {
#       "name": "data_exploration",
#       "confidence": 0.0
#     },
#     {
#       "name": "describe_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "visualize",
#       "confidence": 0.0
#     },
#     {
#       "name": "clean_data",
#       "confidence": 0.0
#     }
#   ],
#   "text": "can you build a logistic regression model"
# }

# %%
text = interpreter.parse('can you build svm classifier')

# %%
text
# Out:
# {'intent': {'name': 'build_model', 'confidence': 0.8847762942314148},
#  'entities': [],
#  'intent_ranking': [{'name': 'build_model', 'confidence': 0.8847762942314148},
#   {'name': 'upload_data', 'confidence': 0.19827713072299957},
#   {'name': 'visualize', 'confidence': 0.07413578033447266},
#   {'name': 'features', 'confidence': 0.0},
#   {'name': 'describe_data', 'confidence': 0.0},
#   {'name': 'clean_data', 'confidence': 0.0},
#   {'name': 'data_exploration', 'confidence': 0.0}],
#  'text': 'can you build svm classifier'}

# %%
text['intent']['name']
# Out:
# 'build_model'

# %%
text['entities'][0]['value']
# Out:
# 'logistic regression'

# %%
text = interpreter.parse('show me the top 6 rows')

# %%
text['intent']['name']
# Out:
# 'data_exploration'

# %%
text
# Out:
# {'intent': {'name': 'data_exploration', 'confidence': 0.9552827477455139},
#  'entities': [{'start': 12,
#    'end': 15,
#    'value': 'top',
#    'entity': 'head',
#    'confidence': 0.5877959978128657,
#    'extractor': 'ner_crf'},
#   {'start': 16,
#    'end': 17,
#    'value': '6',
#    'entity': 'number',
#    'confidence': 0.7663835753794138,
#    'extractor': 'ner_crf'}],
#  'intent_ranking': [{'name': 'data_exploration',
#    'confidence': 0.9552827477455139},
#   {'name': 'build_model', 'confidence': 0.07951666414737701},
#   {'name': 'describe_data', 'confidence': 0.014630831778049469},
#   {'name': 'upload_data', 'confidence': 0.0},
#   {'name': 'features', 'confidence': 0.0},
#   {'name': 'visualize', 'confidence': 0.0},
#   {'name': 'clean_data', 'confidence': 0.0}],
#  'text': 'show me the top 6 rows'}

# %%
text['intent']['name']
# Out:
# 'data_exploration'

# %%
text['entities'][0]
# Out:
# {'start': 12,
#  'end': 15,
#  'value': 'top',
#  'entity': 'head',
#  'confidence': 0.5877959978128657,
#  'extractor': 'ner_crf'}

# %%
text['entities'][1]
# Out:
# {'start': 16,
#  'end': 17,
#  'value': '6',
#  'entity': 'number',
#  'confidence': 0.7663835753794138,
#  'extractor': 'ner_crf'}

# %%
print(text['entities'][0]['value'])
print(text['entities'][0]['entity'])
# Out:
# top
# head

# %%
print(text['entities'][1]['value'])
print(text['entities'][1]['entity'])
# Out:
# 6
# number

# %%
text = interpreter.parse('show me the top seven rows')

# %%
text['entities']
# Out:
# [{'start': 12,
#   'end': 15,
#   'value': 'top',
#   'entity': 'head',
#   'confidence': 0.8333276383983339,
#   'extractor': 'ner_crf'},
#  {'start': 16,
#   'end': 21,
#   'value': 'seven',
#   'entity': 'number',
#   'confidence': 0.8239209491530686,
#   'extractor': 'ner_crf'}]

# %%
intent_print(interpreter.parse('Can you build a k neighbors classifier'))
# Out:
# {
#   "intent": {
#     "name": "build_model",
#     "confidence": 0.9350064992904663
#   },
#   "entities": [
#     {
#       "start": 16,
#       "end": 27,
#       "value": "kneighbors",
#       "entity": "model_name",
#       "confidence": 0.8552410738952514,
#       "extractor": "ner_crf",
#       "processors": [
#         "ner_synonyms"
#       ]
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "build_model",
#       "confidence": 0.9350064992904663
#     },
#     {
#       "name": "upload_data",
#       "confidence": 0.12197951972484589
#     },
#     {
#       "name": "data_exploration",
#       "confidence": 0.11487428843975067
#     },
#     {
#       "name": "features",
#       "confidence": 0.06762079149484634
#     },
#     {
#       "name": "describe_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "clean_data",
#       "confidence": 0.0
#     },
#     {
#       "name": "visualize",
#       "confidence": 0.0
#     }
#   ],
#   "text": "Can you build a k neighbors classifier"
# }
